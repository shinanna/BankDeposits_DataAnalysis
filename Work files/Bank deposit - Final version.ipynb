# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

# %%
data=pd.read_excel('/Users/dehilinesma/Downloads/4 - Bank Deposits.xlsx')
data
# Out:
#       age          job  marital  education default  balance housing loan  \
# 0      26  blue-collar  married    primary      no        0     yes   no
# 1      26   unemployed   single  secondary      no     1064      no   no
# 2      26      student   single  secondary      no     2572     yes   no
# 3      26   technician   single   tertiary      no     1216     yes   no
# 4      26   technician  married   tertiary      no     3825     yes   no
# ...   ...          ...      ...        ...     ...      ...     ...  ...
# 2323   18      student   single  secondary      no      156      no   no
# 2324   18      student   single    primary      no      608      no   no
# 2325   18      student   single    unknown      no      108      no   no
# 2326   18      student   single    unknown      no      348      no   no
# 2327   18      student   single    unknown      no      438      no   no
#
#        contact  day month  duration  campaign  pdays  previous poutcome  \
# 0      unknown   21   may       425         1   -1.0         0  unknown
# 1      unknown   31   may       113         1   -1.0         0  unknown
# 2     cellular    5   may       620         1   -1.0         0  unknown
# 3     cellular   16   apr       472         2   -1.0         0  unknown
# 4      unknown   13   may       107         1   -1.0         0  unknown
# ...        ...  ...   ...       ...       ...    ...       ...      ...
# 2323  cellular    4   nov       298         2    NaN         4    other
# 2324  cellular   13   nov       210         1    NaN         1  success
# 2325  cellular    9   feb        92         1    NaN         1  success
# 2326  cellular    5   may       443         4   -1.0         0  unknown
# 2327  cellular    1   sep       425         1   -1.0         0  unknown
#
#      Subscription to deposit (target)
# 0                                  no
# 1                                  no
# 2                                  no
# 3                                  no
# 4                                  no
# ...                               ...
# 2323                               no
# 2324                              yes
# 2325                              yes
# 2326                              yes
# 2327                               no
#
# [2328 rows x 17 columns]

# %%
data.dtypes
# Out:
# age                                   int64
# job                                  object
# marital                              object
# education                            object
# default                              object
# balance                               int64
# housing                              object
# loan                                 object
# contact                              object
# day                                   int64
# month                                object
# duration                              int64
# campaign                              int64
# pdays                               float64
# previous                              int64
# poutcome                             object
# Subscription to deposit (target)     object
# dtype: object

# %% [markdown]
# ### At this stage we checked if we had misstyping issues with non numerical data

# %%
for col in data:
    print ('\nFrequency of Categories for varible %s'%col)
    print (data[col].value_counts())
# Out:
# Frequency of Categories for varible age
# 26    881
# 25    571
# 24    326
# 23    222
# 22    138
# 21     86
# 20     53
# 19     39
# 18     12
# Name: age, dtype: int64
#
# Frequency of Categories for varible job
# student          549
# blue-collar      481
# technician       306
# admin.           293
# services         281
# management       236
# unemployed        62
# self-employed     60
# entrepreneur      36
# housemaid         15
# unknown            5
# retired            4
# Name: job, dtype: int64
#
# Frequency of Categories for varible marital
# single      1886
# married      407
# divorced      30
# no             1
# Name: marital, dtype: int64
#
# Frequency of Categories for varible education
# secondary    1492
# tertiary      537
# primary       167
# unknown       127
# Name: education, dtype: int64
#
# Frequency of Categories for varible default
# no     2274
# yes      54
# Name: default, dtype: int64
#
# Frequency of Categories for varible balance
# 0       103
# 2        12
# 3        11
# 1        10
# 5        10
#        ...
# 2532      1
# 1370      1
# 8750      1
# 7628      1
# 438       1
# Name: balance, Length: 1176, dtype: int64
#
# Frequency of Categories for varible housing
# yes    1215
# no     1113
# Name: housing, dtype: int64
#
# Frequency of Categories for varible loan
# no     1959
# yes     369
# Name: loan, dtype: int64
#
# Frequency of Categories for varible contact
# cellular     1534
# unknown       667
# telephone     120
# Name: contact, dtype: int64
#
# Frequency of Categories for varible day
# 18       141
# 28       130
# 15       129
# 4        117
# 30       110
# 27       106
# 8         99
# 13        97
# 5         95
# 12        93
# 7         91
# 16        91
# 3         79
# 6         76
# 29        75
# 14        70
# 9         70
# 26        68
# 23        64
# 21        61
# 19        61
# 2         61
# 17        56
# 20        49
# 11        44
# 22        38
# 24        38
# 25        37
# 10        34
# 1         29
# 31        17
# 430        1
# 12000      1
# Name: day, dtype: int64
#
# Frequency of Categories for varible month
# may    912
# jul    393
# jun    268
# apr    170
# feb    124
# aug    124
# jan     85
# sep     75
# oct     62
# mar     56
# nov     42
# dec     17
# Name: month, dtype: int64
#
# Frequency of Categories for varible duration
# 104     15
# 113     13
# 98      12
# 121     12
# 236     12
#         ..
# 754      1
# 633      1
# 774      1
# 1165     1
# 621      1
# Name: duration, Length: 697, dtype: int64
#
# Frequency of Categories for varible campaign
# 1     1125
# 2      584
# 3      279
# 4      131
# 5       72
# 6       31
# 7       22
# 8       12
# 10      11
# 9        9
# 11       8
# 18       8
# 12       7
# 31       4
# 23       3
# 28       3
# 16       3
# 26       3
# 20       2
# 58       1
# 36       1
# 14       1
# 29       1
# 37       1
# 17       1
# 32       1
# 25       1
# 13       1
# 19       1
# 15       1
# Name: campaign, dtype: int64
#
# Frequency of Categories for varible pdays
# -1.0      1915
#  92.0       17
#  91.0       15
#  182.0      11
#  95.0        9
#           ...
#  463.0       1
#  69.0        1
#  70.0        1
#  118.0       1
#  110.0       1
# Name: pdays, Length: 179, dtype: int64
#
# Frequency of Categories for varible previous
# 0     1917
# 1      144
# 2      114
# 3       51
# 4       35
# 5       21
# 6       13
# 7       11
# 8        7
# 10       5
# 12       4
# 9        2
# 20       1
# 29       1
# 13       1
# 14       1
# Name: previous, dtype: int64
#
# Frequency of Categories for varible poutcome
# unknown    1918
# failure     174
# other       122
# success     114
# Name: poutcome, dtype: int64
#
# Frequency of Categories for varible Subscription to deposit (target)
# no     1844
# yes     484
# Name: Subscription to deposit (target), dtype: int64

# %%
data.duplicated().any()
# Out:
# True

# %%
data.drop_duplicates()
# Out:
#       age          job  marital  education default  balance housing loan  \
# 0      26  blue-collar  married    primary      no        0     yes   no
# 1      26   unemployed   single  secondary      no     1064      no   no
# 2      26      student   single  secondary      no     2572     yes   no
# 3      26   technician   single   tertiary      no     1216     yes   no
# 4      26   technician  married   tertiary      no     3825     yes   no
# ...   ...          ...      ...        ...     ...      ...     ...  ...
# 2323   18      student   single  secondary      no      156      no   no
# 2324   18      student   single    primary      no      608      no   no
# 2325   18      student   single    unknown      no      108      no   no
# 2326   18      student   single    unknown      no      348      no   no
# 2327   18      student   single    unknown      no      438      no   no
#
#        contact  day month  duration  campaign  pdays  previous poutcome  \
# 0      unknown   21   may       425         1   -1.0         0  unknown
# 1      unknown   31   may       113         1   -1.0         0  unknown
# 2     cellular    5   may       620         1   -1.0         0  unknown
# 3     cellular   16   apr       472         2   -1.0         0  unknown
# 4      unknown   13   may       107         1   -1.0         0  unknown
# ...        ...  ...   ...       ...       ...    ...       ...      ...
# 2323  cellular    4   nov       298         2    NaN         4    other
# 2324  cellular   13   nov       210         1    NaN         1  success
# 2325  cellular    9   feb        92         1    NaN         1  success
# 2326  cellular    5   may       443         4   -1.0         0  unknown
# 2327  cellular    1   sep       425         1   -1.0         0  unknown
#
#      Subscription to deposit (target)
# 0                                  no
# 1                                  no
# 2                                  no
# 3                                  no
# 4                                  no
# ...                               ...
# 2323                               no
# 2324                              yes
# 2325                              yes
# 2326                              yes
# 2327                               no
#
# [2143 rows x 17 columns]

# %% [markdown]
# ### We proceeded in finding outliers

# %%
data.describe()
# Out:
#                age       balance           day     duration     campaign  \
# count  2328.000000  2.328000e+03   2328.000000  2328.000000  2328.000000
# mean     24.471649  5.255143e+03     21.123282   275.316151     2.446306
# std       1.780876  2.072469e+05    248.680549   244.516521     3.370369
# min      18.000000 -8.019000e+03      1.000000     3.000000     1.000000
# 25%      24.000000  7.600000e+01      8.000000   113.000000     1.000000
# 50%      25.000000  3.505000e+02     15.000000   206.500000     2.000000
# 75%      26.000000  1.003250e+03     24.000000   354.250000     3.000000
# max      26.000000  1.000000e+07  12000.000000  1992.000000    58.000000
#
#              pdays     previous
# count  2323.000000  2328.000000
# mean     35.482996     0.503866
# std      92.897891     1.585816
# min      -1.000000     0.000000
# 25%      -1.000000     0.000000
# 50%      -1.000000     0.000000
# 75%      -1.000000     0.000000
# max     485.000000    29.000000

# %%
data[(data['campaign']==58)]
# Out:
#       age         job marital education default  balance housing loan  \
# 1574   24  technician  single   primary      no      126     yes   no
#
#       contact  day month  duration  campaign  pdays  previous poutcome  \
# 1574  unknown   20   jun        10        58   -1.0         0  unknown
#
#      Subscription to deposit (target)
# 1574                               no

# %%
data[(data['duration']==1992)]
# Out:
#      age         job   marital education default  balance housing loan  \
# 273   26  technician  divorced  tertiary      no      -70      no  yes
#
#      contact  day month  duration  campaign  pdays  previous poutcome  \
# 273  unknown    1   jul      1992         2   -1.0         0  unknown
#
#     Subscription to deposit (target)
# 273                               no

# %%
data[(data['balance']== 1.000000e+07)]
# Out:
#     age         job marital education default   balance housing loan  contact  \
# 16   26  management  single  tertiary      no  10000000      no   no  unknown
#
#     day month  duration  campaign  pdays  previous poutcome  \
# 16   26   may       111         1   -1.0         0  unknown
#
#    Subscription to deposit (target)
# 16                               no

# %%
data[(data['balance']== -8.019000e+03)]
# Out:
#      age          job marital  education default  balance housing loan  \
# 285   26  blue-collar  single  secondary     yes    -8019      no  yes
#
#       contact  day month  duration  campaign  pdays  previous poutcome  \
# 285  cellular    7   jul       299         3   -1.0         0  unknown
#
#     Subscription to deposit (target)
# 285                               no

# %%
data[(data['day']>31)]
# Out:
#       age         job  marital  education default  balance housing loan  \
# 1576   24  management  married  secondary      no      867     yes   no
# 1589   24     student   single  secondary      no     1250      no   no
#
#        contact    day month  duration  campaign  pdays  previous poutcome  \
# 1576   unknown    430   jun       546        10   -1.0         0  unknown
# 1589  cellular  12000   mar       411         2   -1.0         0  unknown
#
#      Subscription to deposit (target)
# 1576                              yes
# 1589                              yes

# %% [markdown]
# ### We later decided to drop the maximum balance as it was altering the values and changing the days with the median day

# %%
data[(data['day']>31)]
data.at[1576,'day']=15
data.at[1589,'day']=15

# %%
data=data.drop([16])

# %%
data=data.drop([285])

# %% [markdown]
# ### Locate empty cells and changing them

# %%
data.isna().sum()
# Out:
# age                                 0
# job                                 0
# marital                             4
# education                           5
# default                             0
# balance                             0
# housing                             0
# loan                                0
# contact                             7
# day                                 0
# month                               0
# duration                            0
# campaign                            0
# pdays                               5
# previous                            0
# poutcome                            0
# Subscription to deposit (target)    0
# dtype: int64

# %% [markdown]
# ## Filling empty cells
# ### Finding the strategy of filling the empty cells
# #### We replayced by single since the profiles were 18yo students

# %%
data[data['marital'].isnull()]
data[(data['age']== 18) & (data['marital'])]
# Out:
#       age      job marital  education default  balance housing loan   contact  \
# 2320   18  student  single  secondary      no        5      no   no  cellular
# 2321   18  student  single    unknown      no        3      no   no  cellular
# 2322   18  student  single    unknown      no      108      no   no  cellular
# 2323   18  student  single  secondary      no      156      no   no  cellular
# 2324   18  student  single    primary      no      608      no   no  cellular
# 2325   18  student  single    unknown      no      108      no   no  cellular
# 2326   18  student  single    unknown      no      348      no   no  cellular
# 2327   18  student  single    unknown      no      438      no   no  cellular
#
#       day month  duration  campaign  pdays  previous poutcome  \
# 2320   24   aug       143         2   -1.0         0  unknown
# 2321   25   aug       130         2    NaN         0  unknown
# 2322    8   sep       169         1    NaN         0  unknown
# 2323    4   nov       298         2    NaN         4    other
# 2324   13   nov       210         1    NaN         1  success
# 2325    9   feb        92         1    NaN         1  success
# 2326    5   may       443         4   -1.0         0  unknown
# 2327    1   sep       425         1   -1.0         0  unknown
#
#      Subscription to deposit (target)
# 2320                               no
# 2321                              yes
# 2322                              yes
# 2323                               no
# 2324                              yes
# 2325                              yes
# 2326                              yes
# 2327                               no

# %%
data['marital'].fillna('single', inplace=True)

# %%
data[(data['poutcome']=='unknown') & (data['pdays']== -1)]
# Out:
#       age          job  marital  education default  balance housing loan  \
# 0      26  blue-collar  married    primary      no        0     yes   no
# 1      26   unemployed   single  secondary      no     1064      no   no
# 2      26      student   single  secondary      no     2572     yes   no
# 3      26   technician   single   tertiary      no     1216     yes   no
# 4      26   technician  married   tertiary      no     3825     yes   no
# ...   ...          ...      ...        ...     ...      ...     ...  ...
# 2318   18      student   single    primary      no      608      no   no
# 2319   18      student   single    unknown      no       35      no   no
# 2320   18      student   single  secondary      no        5      no   no
# 2326   18      student   single    unknown      no      348      no   no
# 2327   18      student   single    unknown      no      438      no   no
#
#         contact  day month  duration  campaign  pdays  previous poutcome  \
# 0       unknown   21   may       425         1   -1.0         0  unknown
# 1       unknown   31   may       113         1   -1.0         0  unknown
# 2      cellular    5   may       620         1   -1.0         0  unknown
# 3      cellular   16   apr       472         2   -1.0         0  unknown
# 4       unknown   13   may       107         1   -1.0         0  unknown
# ...         ...  ...   ...       ...       ...    ...       ...      ...
# 2318   cellular   12   aug       267         1   -1.0         0  unknown
# 2319  telephone   21   aug       104         2   -1.0         0  unknown
# 2320   cellular   24   aug       143         2   -1.0         0  unknown
# 2326   cellular    5   may       443         4   -1.0         0  unknown
# 2327   cellular    1   sep       425         1   -1.0         0  unknown
#
#      Subscription to deposit (target)
# 0                                  no
# 1                                  no
# 2                                  no
# 3                                  no
# 4                                  no
# ...                               ...
# 2318                              yes
# 2319                               no
# 2320                               no
# 2326                              yes
# 2327                               no
#
# [1913 rows x 17 columns]

# %% [markdown]
# #### Instead of nan we replayced with unknown for both education and contact

# %%
data[data['education'].isnull()]
data['education'].fillna('unknown', inplace=True)

# %%
data[data['contact'].isnull()]
data['contact'].fillna('unknown', inplace=True)

# %% [markdown]
# #### When it came to pdays: We first proceeded in finding that all unknown in 'poutcome' are -1 in 'pdays'

# %%
data[data['pdays'].isnull()]
# Out:
#       age      job marital  education default  balance housing loan   contact  \
# 2321   18  student  single    unknown      no        3      no   no  cellular
# 2322   18  student  single    unknown      no      108      no   no  cellular
# 2323   18  student  single  secondary      no      156      no   no  cellular
# 2324   18  student  single    primary      no      608      no   no  cellular
# 2325   18  student  single    unknown      no      108      no   no  cellular
#
#       day month  duration  campaign  pdays  previous poutcome  \
# 2321   25   aug       130         2    NaN         0  unknown
# 2322    8   sep       169         1    NaN         0  unknown
# 2323    4   nov       298         2    NaN         4    other
# 2324   13   nov       210         1    NaN         1  success
# 2325    9   feb        92         1    NaN         1  success
#
#      Subscription to deposit (target)
# 2321                              yes
# 2322                              yes
# 2323                               no
# 2324                              yes
# 2325                              yes

# %%
data[(data['poutcome']=='unknown') & (data['pdays']== -1)]
# Out:
#       age          job  marital  education default  balance housing loan  \
# 0      26  blue-collar  married    primary      no        0     yes   no
# 1      26   unemployed   single  secondary      no     1064      no   no
# 2      26      student   single  secondary      no     2572     yes   no
# 3      26   technician   single   tertiary      no     1216     yes   no
# 4      26   technician  married   tertiary      no     3825     yes   no
# ...   ...          ...      ...        ...     ...      ...     ...  ...
# 2318   18      student   single    primary      no      608      no   no
# 2319   18      student   single    unknown      no       35      no   no
# 2320   18      student   single  secondary      no        5      no   no
# 2326   18      student   single    unknown      no      348      no   no
# 2327   18      student   single    unknown      no      438      no   no
#
#         contact  day month  duration  campaign  pdays  previous poutcome  \
# 0       unknown   21   may       425         1   -1.0         0  unknown
# 1       unknown   31   may       113         1   -1.0         0  unknown
# 2      cellular    5   may       620         1   -1.0         0  unknown
# 3      cellular   16   apr       472         2   -1.0         0  unknown
# 4       unknown   13   may       107         1   -1.0         0  unknown
# ...         ...  ...   ...       ...       ...    ...       ...      ...
# 2318   cellular   12   aug       267         1   -1.0         0  unknown
# 2319  telephone   21   aug       104         2   -1.0         0  unknown
# 2320   cellular   24   aug       143         2   -1.0         0  unknown
# 2326   cellular    5   may       443         4   -1.0         0  unknown
# 2327   cellular    1   sep       425         1   -1.0         0  unknown
#
#      Subscription to deposit (target)
# 0                                  no
# 1                                  no
# 2                                  no
# 3                                  no
# 4                                  no
# ...                               ...
# 2318                              yes
# 2319                               no
# 2320                               no
# 2326                              yes
# 2327                               no
#
# [1913 rows x 17 columns]

# %% [markdown]
# #### When it came to success and others, we replayced by the mean of the data in same range

# %%
pdays=data[(data['poutcome']=='success') & (data['pdays'])]
pdays
# Out:
#       age            job marital  education default  balance housing loan  \
# 12     26         admin.  single  secondary      no      255      no   no
# 62     26        student  single   tertiary      no      294      no   no
# 543    26  self-employed  single  secondary      no     1242     yes   no
# 595    26    blue-collar  single    primary      no       52     yes   no
# 609    26         admin.  single  secondary      no      255      no   no
# ...   ...            ...     ...        ...     ...      ...     ...  ...
# 2302   19        student  single    primary      no      103      no   no
# 2306   19        student  single    unknown      no      108      no   no
# 2308   19        student  single  secondary      no      329      no   no
# 2309   19        student  single    primary      no      608      no   no
# 2314   19        student  single    unknown      no      108      no   no
#
#        contact  day month  duration  campaign  pdays  previous poutcome  \
# 12    cellular   30   apr       457         1   80.0         1  success
# 62    cellular    5   mar        87         1   91.0         2  success
# 543   cellular    5   feb       205         2  253.0         2  success
# 595   cellular   20   apr       271         1  300.0         2  success
# 609   cellular   30   apr       457         1   80.0         1  success
# ...        ...  ...   ...       ...       ...    ...       ...      ...
# 2302  cellular   15   oct        96         2   97.0         2  success
# 2306  cellular    9   mar       273         2  182.0         1  success
# 2308  cellular   30   apr       169         1  190.0         2  success
# 2309  cellular   12   may       236         1  180.0         2  success
# 2314  cellular   10   aug       168         1  182.0         2  success
#
#      Subscription to deposit (target)
# 12                                yes
# 62                                yes
# 543                                no
# 595                                no
# 609                               yes
# ...                               ...
# 2302                               no
# 2306                              yes
# 2308                              yes
# 2309                              yes
# 2314                              yes
#
# [112 rows x 17 columns]

# %%
pdays.describe()
# Out:
#               age       balance         day     duration    campaign  \
# count  112.000000    112.000000  112.000000   112.000000  112.000000
# mean    23.937500   1107.491071   15.241071   273.973214    1.794643
# std      2.054576   2497.024193    9.012749   178.125953    1.501581
# min     19.000000    -67.000000    1.000000    68.000000    1.000000
# 25%     22.750000    215.000000    8.000000   163.000000    1.000000
# 50%     24.000000    471.500000   13.000000   236.000000    1.000000
# 75%     26.000000   1234.000000   24.000000   328.000000    2.000000
# max     26.000000  23878.000000   30.000000  1178.000000   11.000000
#
#             pdays    previous
# count  112.000000  112.000000
# mean   135.821429    2.767857
# std     58.093000    2.176791
# min     50.000000    1.000000
# 25%     92.000000    1.000000
# 50%    102.500000    2.000000
# 75%    182.000000    3.000000
# max    350.000000   12.000000

# %%
data.at[2321,'pdays']=-1
data.at[2322,'pdays']=-1
data.at[2323,'pdays']=135
data.at[2324,'pdays']=135
data.at[2325,'pdays']=135

# %% [markdown]
# ### Checking that the code ran correctly

# %%
data.isna().sum()
# Out:
# age                                 0
# job                                 0
# marital                             0
# education                           0
# default                             0
# balance                             0
# housing                             0
# loan                                0
# contact                             0
# day                                 0
# month                               0
# duration                            0
# campaign                            0
# pdays                               0
# previous                            0
# poutcome                            0
# Subscription to deposit (target)    0
# dtype: int64

# %%
data.describe()
# Out:
#                age       balance          day     duration     campaign  \
# count  2326.000000   2326.000000  2326.000000  2326.000000  2326.000000
# mean     24.470335    963.883061    15.796217   275.376612     2.446690
# std       1.781078   2043.794915     8.787758   244.597428     3.371665
# min      18.000000  -1414.000000     1.000000     3.000000     1.000000
# 25%      24.000000     76.000000     8.000000   113.000000     1.000000
# 50%      25.000000    350.500000    15.000000   206.500000     2.000000
# 75%      26.000000   1003.000000    23.000000   354.750000     3.000000
# max      26.000000  24299.000000    31.000000  1992.000000    58.000000
#
#              pdays     previous
# count  2326.000000  2326.000000
# mean     35.611350     0.504299
# std      92.906647     1.586429
# min      -1.000000     0.000000
# 25%      -1.000000     0.000000
# 50%      -1.000000     0.000000
# 75%      -1.000000     0.000000
# max     485.000000    29.000000

# %% [markdown]
# ## Exporting the file to MySQL

# %%
#data.to_csv('/Users/dehilinesma/Downloads/Bank deposit - Before encoding1 .csv')

# %% [markdown]
# ## Label Encoding

# %%
month_labels = {'jan': 1, 'feb': 2, 'mar': 3, 'apr': 4, 'may': 5, 'jun': 6, 'jul': 7, 'aug': 8, 'sep': 9, 'oct': 10, 'nov': 11, 'dec': 12}
data['month'] = data['month'].apply(lambda x: month_labels[x])

data
# Out:
#       age          job  marital  education default  balance housing loan  \
# 0      26  blue-collar  married    primary      no        0     yes   no
# 1      26   unemployed   single  secondary      no     1064      no   no
# 2      26      student   single  secondary      no     2572     yes   no
# 3      26   technician   single   tertiary      no     1216     yes   no
# 4      26   technician  married   tertiary      no     3825     yes   no
# ...   ...          ...      ...        ...     ...      ...     ...  ...
# 2323   18      student   single  secondary      no      156      no   no
# 2324   18      student   single    primary      no      608      no   no
# 2325   18      student   single    unknown      no      108      no   no
# 2326   18      student   single    unknown      no      348      no   no
# 2327   18      student   single    unknown      no      438      no   no
#
#        contact  day  month  duration  campaign  pdays  previous poutcome  \
# 0      unknown   21      5       425         1   -1.0         0  unknown
# 1      unknown   31      5       113         1   -1.0         0  unknown
# 2     cellular    5      5       620         1   -1.0         0  unknown
# 3     cellular   16      4       472         2   -1.0         0  unknown
# 4      unknown   13      5       107         1   -1.0         0  unknown
# ...        ...  ...    ...       ...       ...    ...       ...      ...
# 2323  cellular    4     11       298         2  135.0         4    other
# 2324  cellular   13     11       210         1  135.0         1  success
# 2325  cellular    9      2        92         1  135.0         1  success
# 2326  cellular    5      5       443         4   -1.0         0  unknown
# 2327  cellular    1      9       425         1   -1.0         0  unknown
#
#      Subscription to deposit (target)
# 0                                  no
# 1                                  no
# 2                                  no
# 3                                  no
# 4                                  no
# ...                               ...
# 2323                               no
# 2324                              yes
# 2325                              yes
# 2326                              yes
# 2327                               no
#
# [2326 rows x 17 columns]

# %%
poutcome_labels = {'unknown': 0, 'failure': 1,'other': 2, 'success': 3}
data['poutcome'] = data['poutcome'].apply(lambda x: poutcome_labels[x])
data
# Out:
#       age          job  marital  education default  balance housing loan  \
# 0      26  blue-collar  married    primary      no        0     yes   no
# 1      26   unemployed   single  secondary      no     1064      no   no
# 2      26      student   single  secondary      no     2572     yes   no
# 3      26   technician   single   tertiary      no     1216     yes   no
# 4      26   technician  married   tertiary      no     3825     yes   no
# ...   ...          ...      ...        ...     ...      ...     ...  ...
# 2323   18      student   single  secondary      no      156      no   no
# 2324   18      student   single    primary      no      608      no   no
# 2325   18      student   single    unknown      no      108      no   no
# 2326   18      student   single    unknown      no      348      no   no
# 2327   18      student   single    unknown      no      438      no   no
#
#        contact  day  month  duration  campaign  pdays  previous  poutcome  \
# 0      unknown   21      5       425         1   -1.0         0         0
# 1      unknown   31      5       113         1   -1.0         0         0
# 2     cellular    5      5       620         1   -1.0         0         0
# 3     cellular   16      4       472         2   -1.0         0         0
# 4      unknown   13      5       107         1   -1.0         0         0
# ...        ...  ...    ...       ...       ...    ...       ...       ...
# 2323  cellular    4     11       298         2  135.0         4         2
# 2324  cellular   13     11       210         1  135.0         1         3
# 2325  cellular    9      2        92         1  135.0         1         3
# 2326  cellular    5      5       443         4   -1.0         0         0
# 2327  cellular    1      9       425         1   -1.0         0         0
#
#      Subscription to deposit (target)
# 0                                  no
# 1                                  no
# 2                                  no
# 3                                  no
# 4                                  no
# ...                               ...
# 2323                               no
# 2324                              yes
# 2325                              yes
# 2326                              yes
# 2327                               no
#
# [2326 rows x 17 columns]

# %%
contact_labels = {'unknown': 0, 'cellular': 1,'telephone': 2,}
data['contact'] = data['contact'].apply(lambda x: contact_labels[x])
data
# Out:
#       age          job  marital  education default  balance housing loan  \
# 0      26  blue-collar  married    primary      no        0     yes   no
# 1      26   unemployed   single  secondary      no     1064      no   no
# 2      26      student   single  secondary      no     2572     yes   no
# 3      26   technician   single   tertiary      no     1216     yes   no
# 4      26   technician  married   tertiary      no     3825     yes   no
# ...   ...          ...      ...        ...     ...      ...     ...  ...
# 2323   18      student   single  secondary      no      156      no   no
# 2324   18      student   single    primary      no      608      no   no
# 2325   18      student   single    unknown      no      108      no   no
# 2326   18      student   single    unknown      no      348      no   no
# 2327   18      student   single    unknown      no      438      no   no
#
#       contact  day  month  duration  campaign  pdays  previous  poutcome  \
# 0           0   21      5       425         1   -1.0         0         0
# 1           0   31      5       113         1   -1.0         0         0
# 2           1    5      5       620         1   -1.0         0         0
# 3           1   16      4       472         2   -1.0         0         0
# 4           0   13      5       107         1   -1.0         0         0
# ...       ...  ...    ...       ...       ...    ...       ...       ...
# 2323        1    4     11       298         2  135.0         4         2
# 2324        1   13     11       210         1  135.0         1         3
# 2325        1    9      2        92         1  135.0         1         3
# 2326        1    5      5       443         4   -1.0         0         0
# 2327        1    1      9       425         1   -1.0         0         0
#
#      Subscription to deposit (target)
# 0                                  no
# 1                                  no
# 2                                  no
# 3                                  no
# 4                                  no
# ...                               ...
# 2323                               no
# 2324                              yes
# 2325                              yes
# 2326                              yes
# 2327                               no
#
# [2326 rows x 17 columns]

# %% [markdown]
# ### Running a quick analysis on the data to check if the results are consistent

# %%
plt.figure(figsize=(7, 5))
data.boxplot(column=['balance'])
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Automatic encoding

# %%
from sklearn.preprocessing import LabelEncoder
encoder=LabelEncoder()


for i in data:
    if data[i].dtype=="object":
        print(i)
        data[i]=encoder.fit_transform(data[i])
data
# Out:
# job
# marital
# education
# default
# housing
# loan
# Subscription to deposit (target)
#       age  job  marital  education  default  balance  housing  loan  contact  \
# 0      26    1        1          0        0        0        1     0        0
# 1      26   10        3          1        0     1064        0     0        0
# 2      26    8        3          1        0     2572        1     0        1
# 3      26    9        3          2        0     1216        1     0        1
# 4      26    9        1          2        0     3825        1     0        0
# ...   ...  ...      ...        ...      ...      ...      ...   ...      ...
# 2323   18    8        3          1        0      156        0     0        1
# 2324   18    8        3          0        0      608        0     0        1
# 2325   18    8        3          3        0      108        0     0        1
# 2326   18    8        3          3        0      348        0     0        1
# 2327   18    8        3          3        0      438        0     0        1
#
#       day  month  duration  campaign  pdays  previous  poutcome  \
# 0      21      5       425         1   -1.0         0         0
# 1      31      5       113         1   -1.0         0         0
# 2       5      5       620         1   -1.0         0         0
# 3      16      4       472         2   -1.0         0         0
# 4      13      5       107         1   -1.0         0         0
# ...   ...    ...       ...       ...    ...       ...       ...
# 2323    4     11       298         2  135.0         4         2
# 2324   13     11       210         1  135.0         1         3
# 2325    9      2        92         1  135.0         1         3
# 2326    5      5       443         4   -1.0         0         0
# 2327    1      9       425         1   -1.0         0         0
#
#       Subscription to deposit (target)
# 0                                    0
# 1                                    0
# 2                                    0
# 3                                    0
# 4                                    0
# ...                                ...
# 2323                                 0
# 2324                                 1
# 2325                                 1
# 2326                                 1
# 2327                                 0
#
# [2326 rows x 17 columns]

# %%
df=data.corr()
df.round(decimals = 2)
# Out:
#                                    age   job  marital  education  default  \
# age                               1.00 -0.19    -0.16      -0.01     0.06
# job                              -0.19  1.00     0.15       0.16    -0.04
# marital                          -0.16  0.15     1.00       0.09    -0.09
# education                        -0.01  0.16     0.09       1.00    -0.05
# default                           0.06 -0.04    -0.09      -0.05     1.00
# balance                           0.02  0.09     0.08       0.08    -0.09
# housing                           0.13 -0.22    -0.24      -0.17     0.07
# loan                              0.13 -0.08    -0.12      -0.06     0.13
# contact                          -0.06  0.15     0.16       0.10    -0.06
# day                               0.07 -0.03    -0.05       0.00     0.01
# month                            -0.10  0.07     0.02      -0.02     0.01
# duration                          0.08 -0.02    -0.04      -0.02    -0.02
# campaign                          0.03  0.00    -0.05      -0.06     0.02
# pdays                            -0.04  0.02     0.04      -0.01    -0.04
# previous                         -0.05  0.04     0.05      -0.01    -0.04
# poutcome                         -0.09  0.08     0.10       0.01    -0.05
# Subscription to deposit (target) -0.12  0.10     0.13       0.06    -0.04
#
#                                   balance  housing  loan  contact   day  \
# age                                  0.02     0.13  0.13    -0.06  0.07
# job                                  0.09    -0.22 -0.08     0.15 -0.03
# marital                              0.08    -0.24 -0.12     0.16 -0.05
# education                            0.08    -0.17 -0.06     0.10  0.00
# default                             -0.09     0.07  0.13    -0.06  0.01
# balance                              1.00    -0.07 -0.09     0.06 -0.00
# housing                             -0.07     1.00  0.04    -0.42  0.02
# loan                                -0.09     0.04  1.00    -0.05 -0.00
# contact                              0.06    -0.42 -0.05     1.00 -0.05
# day                                 -0.00     0.02 -0.00    -0.05  1.00
# month                               -0.01    -0.16  0.04     0.07 -0.10
# duration                            -0.00     0.02  0.03    -0.00 -0.02
# campaign                            -0.04     0.06  0.06    -0.02  0.13
# pdays                                0.00     0.03 -0.06     0.22 -0.05
# previous                             0.03    -0.07 -0.06     0.18 -0.04
# poutcome                             0.03    -0.15 -0.10     0.24 -0.04
# Subscription to deposit (target)     0.04    -0.28 -0.09     0.19  0.01
#
#                                   month  duration  campaign  pdays  previous  \
# age                               -0.10      0.08      0.03  -0.04     -0.05
# job                                0.07     -0.02      0.00   0.02      0.04
# marital                            0.02     -0.04     -0.05   0.04      0.05
# education                         -0.02     -0.02     -0.06  -0.01     -0.01
# default                            0.01     -0.02      0.02  -0.04     -0.04
# balance                           -0.01     -0.00     -0.04   0.00      0.03
# housing                           -0.16      0.02      0.06   0.03     -0.07
# loan                               0.04      0.03      0.06  -0.06     -0.06
# contact                            0.07     -0.00     -0.02   0.22      0.18
# day                               -0.10     -0.02      0.13  -0.05     -0.04
# month                              1.00     -0.03      0.02  -0.02      0.03
# duration                          -0.03      1.00     -0.12  -0.01      0.04
# campaign                           0.02     -0.12      1.00  -0.04     -0.02
# pdays                             -0.02     -0.01     -0.04   1.00      0.55
# previous                           0.03      0.04     -0.02   0.55      1.00
# poutcome                           0.08     -0.02     -0.06   0.69      0.63
# Subscription to deposit (target)   0.08      0.35     -0.08   0.07      0.14
#
#                                   poutcome  Subscription to deposit (target)
# age                                  -0.09                             -0.12
# job                                   0.08                              0.10
# marital                               0.10                              0.13
# education                             0.01                              0.06
# default                              -0.05                             -0.04
# balance                               0.03                              0.04
# housing                              -0.15                             -0.28
# loan                                 -0.10                             -0.09
# contact                               0.24                              0.19
# day                                  -0.04                              0.01
# month                                 0.08                              0.08
# duration                             -0.02                              0.35
# campaign                             -0.06                             -0.08
# pdays                                 0.69                              0.07
# previous                              0.63                              0.14
# poutcome                              1.00                              0.24
# Subscription to deposit (target)      0.24                              1.00

# %% [markdown]
# ## Decision Tree implementation

# %%
data.columns
feature_cols = ['age', 'job','marital','education','default','balance', 'housing','loan','contact','day','previous','poutcome']

features=data[feature_cols]
target=data["Subscription to deposit (target)"]

# %%
from sklearn.model_selection import train_test_split 
x_train, x_test, y_train, y_test = train_test_split(features, target, test_size=0.3, random_state=1)

# %%
from sklearn.tree import DecisionTreeClassifier 
from sklearn import tree

# %%
clf0 = DecisionTreeClassifier(max_depth=2)
model = clf0.fit(x_train, y_train)
text_representation = tree.export_text(clf0)

# %%
import matplotlib.pyplot as plt
fig = plt.figure(figsize=(25,20))
_ = tree.plot_tree(clf0, 
                   feature_names=feature_cols,  
    
                   filled=True)
fig.savefig("decistion_tree.png")

# %%
#data.to_csv('/Users/dehilinesma/Downloads/Bank deposit - Final version.csv')
